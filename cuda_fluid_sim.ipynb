# %% [markdown]
# # CUDA Fluid Simulation
#
# This notebook demonstrates a CUDA-based fluid simulation.
#
# ## Setup

# %%
# !git clone https://github.com/tarun-bandi/cuda-fluid-sim.git
# %cd cuda-fluid-sim

# %%
# !apt-get update
# !apt-get install -y nvidia-cuda-toolkit
# !pip install numpy matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simple fluid visualization
N = 64
T = np.random.random((N,N))
plt.imshow(T, cmap=hot)
plt.title(Temperature Field)
plt.show()
